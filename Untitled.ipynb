# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
#Reading and Loading the data
dfs = pd.read_csv('parkinsons/parkinsons.data')

# %%
#Getting basic info about the data
print(dfs.shape)
print(dfs.info())
dfs.head()
# Out:
# (195, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
#Getting basic stats about the data
dfs.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
#Find missing values in our dataset:
dfs.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
#Check if we have any duplicated data
dfs.duplicated().sum()
# Out:
# 0

# %%
#It appears there is no column with a missing value, and no duplicated data.
#We can get rid of the name column before plotting our data, as it is not relevant
dfs.drop(columns='name', inplace = True)

# %%
#Engineer new feature for the frequency range:
dfs['range'] = dfs['MDVP:Fhi(Hz)'] - dfs['MDVP:Flo(Hz)']
print(dfs.head())
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
# ...

# %%
# Histogram of the data
dfs.hist(figsize=(25,20))
# Out:
# array([[<Axes: title={'center': 'MDVP:Fo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Fhi(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Flo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(%)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(Abs)'}>],
#        [<Axes: title={'center': 'MDVP:RAP'}>,
#         <Axes: title={'center': 'MDVP:PPQ'}>,
#         <Axes: title={'center': 'Jitter:DDP'}>,
#         <Axes: title={'center': 'MDVP:Shimmer'}>,
#         <Axes: title={'center': 'MDVP:Shimmer(dB)'}>],
#        [<Axes: title={'center': 'Shimmer:APQ3'}>,
#         <Axes: title={'center': 'Shimmer:APQ5'}>,
#         <Axes: title={'center': 'MDVP:APQ'}>,
#         <Axes: title={'center': 'Shimmer:DDA'}>,
#         <Axes: title={'center': 'NHR'}>],
#        [<Axes: title={'center': 'HNR'}>,
#         <Axes: title={'center': 'status'}>,
#         <Axes: title={'center': 'RPDE'}>,
#         <Axes: title={'center': 'DFA'}>,
#         <Axes: title={'center': 'spread1'}>],
# ...

# %%
# Viewing the correlation of the features
corr_matrix = dfs.corr().abs()
fig, ax = plt.subplots(figsize=(20,20))         # Sample figsize in inches
sns.heatmap(corr_matrix, annot=True, cmap='Blues', ax=ax)
plt.show()

# %%
# Extract upper triangle to avoid duplicate values
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Count pairs with correlation > 0.9
num_high_corr_90 = (upper_triangle > 0.9).sum().sum()

# Count pairs with correlation > 0.85
num_high_corr_85 = (upper_triangle > 0.85).sum().sum()

print(f"Number of feature pairs with correlation > 0.9: {num_high_corr_90}")
print(f"Number of feature pairs with correlation > 0.85: {num_high_corr_85}")
# Out:
# Number of feature pairs with correlation > 0.9: 26
# Number of feature pairs with correlation > 0.85: 30

# %%
#Finding feature importance
if 'status' in dfs.columns:
    #Separating the dataset between the features and the target
    X = dfs.drop(columns=['status'])  # Features
    y = dfs['status']  # Target variable

    # Fit a Random Forest model
    rf = RandomForestClassifier(n_estimators=100, random_state=42)
    rf.fit(X, y)

    # Extract feature importances
    feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': rf.feature_importances_})
    feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

    # Display feature importance
    print(feature_importance)

else:
    print("Target variable 'status' is missing. Cannot compute feature importance.")
# Out:
#              Feature  Importance
# 21               PPE    0.131530
# 18           spread1    0.106741
# 0        MDVP:Fo(Hz)    0.087283
# 19           spread2    0.059283
# 2       MDVP:Flo(Hz)    0.058553
# 1       MDVP:Fhi(Hz)    0.052568
# 4   MDVP:Jitter(Abs)    0.040972
# 20                D2    0.038463
# 7         Jitter:DDP    0.038418
# 12          MDVP:APQ    0.036875
# 11      Shimmer:APQ5    0.033096
# 14               NHR    0.032219
# 16              RPDE    0.032186
# 8       MDVP:Shimmer    0.031997
# 3     MDVP:Jitter(%)    0.029920
# 5           MDVP:RAP    0.029836
# 13       Shimmer:DDA    0.029433
# 17               DFA    0.027595
# 22             range    0.027476
# 15               HNR    0.021971
# 6           MDVP:PPQ    0.020675
# 10      Shimmer:APQ3    0.017922
# 9   MDVP:Shimmer(dB)    0.014989

# %%
# Using RandomForest to find feature importance
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X, y)
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': model.feature_importances_})
feature_importance = feature_importance.set_index('Feature')

# Dropping features with high correlation, keeping the most important of the pair
features_to_drop = set()
for column in upper_triangle.columns:
    for index in upper_triangle.index:
        if upper_triangle.loc[index, column] > 0.9:
            # Compare feature importance scores
            if feature_importance.loc[index, 'Importance'] > feature_importance.loc[column, 'Importance']:
                features_to_drop.add(column)  # Drop the less important feature
            else:
                features_to_drop.add(index)

# Drop the selected features
df_reduced = dfs.drop(columns=features_to_drop)
print(df_reduced.head())
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(Abs)  MDVP:APQ  \
# 0      119.992       157.302        74.997           0.00007   0.02971
# 1      122.400       148.650       113.819           0.00008   0.04368
# 2      116.682       131.111       111.555           0.00009   0.03590
# 3      116.676       137.871       111.366           0.00009   0.03772
# 4      116.014       141.781       110.655           0.00011   0.04465
#
#       HNR  status      RPDE       DFA   spread2        D2       PPE   range
# 0  21.033       1  0.414783  0.815285  0.266482  2.301442  0.284654  82.305
# 1  19.085       1  0.458359  0.819521  0.335590  2.486855  0.368674  34.831
# 2  20.651       1  0.429895  0.825288  0.311173  2.342259  0.332634  19.556
# 3  20.644       1  0.434969  0.819235  0.334147  2.405554  0.368975  26.505
# 4  19.649       1  0.417356  0.823484  0.234513  2.332180  0.410335  31.126

# %%
# Getting info about the reduced dataset
print(df_reduced.shape)
print(df_reduced.info())
df_reduced.describe()
# Out:
# (195, 13)
# MDVP:Fo(Hz)         0.591737
# MDVP:Fhi(Hz)        2.542146
# MDVP:Flo(Hz)        1.217350
# MDVP:Jitter(Abs)    2.649071
# MDVP:APQ            2.618047
# HNR                -0.514317
# status             -1.187727
# RPDE               -0.143402
# DFA                -0.033214
# spread2             0.144430
# D2                  0.430384
# PPE                 0.797491
# range               2.629346
# dtype: float64

# %%
# Showing the new skewness
print(df_reduced.skew())

# %%
# Histograms with the remaining features
df_reduced.hist(figsize=(25,20))
# Out:
# array([[<Axes: title={'center': 'MDVP:Fo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Fhi(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Flo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(Abs)'}>],
#        [<Axes: title={'center': 'MDVP:APQ'}>,
#         <Axes: title={'center': 'HNR'}>,
#         <Axes: title={'center': 'status'}>,
#         <Axes: title={'center': 'RPDE'}>],
#        [<Axes: title={'center': 'DFA'}>,
#         <Axes: title={'center': 'spread2'}>,
#         <Axes: title={'center': 'D2'}>, <Axes: title={'center': 'PPE'}>],
#        [<Axes: title={'center': 'range'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Showing correlation of the remaining features
corr_matrix_important_features = df_reduced.corr().abs()
fig, ax = plt.subplots(figsize=(20,20))         # Sample figsize in inches

sns.heatmap(corr_matrix_important_features, annot=True, cmap='Blues', ax=ax)
plt.show()

# %%
#Split the data into features and labels
X = df_reduced.drop(columns='status')
y = df_reduced['status']
print(X.shape)
print(y.shape)
print(X.head())
print(y.head())
# Out:
# (195, 12)
# (195,)
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(Abs)  MDVP:APQ  \
# 0      119.992       157.302        74.997           0.00007   0.02971
# 1      122.400       148.650       113.819           0.00008   0.04368
# 2      116.682       131.111       111.555           0.00009   0.03590
# 3      116.676       137.871       111.366           0.00009   0.03772
# 4      116.014       141.781       110.655           0.00011   0.04465
#
#       HNR      RPDE       DFA   spread2        D2       PPE   range
# 0  21.033  0.414783  0.815285  0.266482  2.301442  0.284654  82.305
# 1  19.085  0.458359  0.819521  0.335590  2.486855  0.368674  34.831
# 2  20.651  0.429895  0.825288  0.311173  2.342259  0.332634  19.556
# 3  20.644  0.434969  0.819235  0.334147  2.405554  0.368975  26.505
# 4  19.649  0.417356  0.823484  0.234513  2.332180  0.410335  31.126
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: status, dtype: int64

# %%
# Out:
# MDVP:Fo(Hz)         0.626440
# MDVP:Fhi(Hz)        0.312909
# MDVP:Flo(Hz)        1.199332
# MDVP:Jitter(Abs)    0.988087
# MDVP:APQ            1.229340
# HNR                -0.103018
# status             -1.085249
# RPDE               -0.082139
# DFA                 0.035786
# spread2             0.044509
# D2                  0.488081
# PPE                 0.433574
# range               0.931153
# dtype: float64

# %%
# Out:
# array([[<Axes: title={'center': 'MDVP:Fo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Fhi(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Flo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(Abs)'}>],
#        [<Axes: title={'center': 'MDVP:APQ'}>,
#         <Axes: title={'center': 'HNR'}>,
#         <Axes: title={'center': 'status'}>,
#         <Axes: title={'center': 'RPDE'}>],
#        [<Axes: title={'center': 'DFA'}>,
#         <Axes: title={'center': 'spread2'}>,
#         <Axes: title={'center': 'D2'}>, <Axes: title={'center': 'PPE'}>],
#        [<Axes: title={'center': 'range'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
X = df_reduced.drop(columns='status')
y = df_reduced['status']
print(X.shape)
print(y.shape)
# Out:
# (195, 12)
# (195,)

# %%
#Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = .8)

# %%
# Scaling the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Logistic Regression.
# Decision Trees
# Random Forest
# Support Vector Machine (SVM)
# Ensemble

# %%
#First model: Logistic regression
logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(X_train, y_train)
logistic_preds = logistic_model.predict(X_test)
print("Logistic Regression Classification Report:")
print(classification_report(y_test, logistic_preds))
# Out:
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        10
#            1       0.91      1.00      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.95      0.85      0.89        39
# weighted avg       0.93      0.92      0.92        39

# %%
# Accuracy score
logistic_accuracy = accuracy_score(y_test, logistic_preds)
print(f"Logistic Regression Accuracy: {logistic_accuracy:.2f}")
# Out:
# Logistic Regression Accuracy: 0.92

# %%
# Comparing results with the actual values
pd.DataFrame({'actual':y_test,'predict':logistic_preds})
# Out:
#      actual  predict
# 83        1        1
# 12        1        1
# 33        0        0
# 113       1        1
# 171       0        1
# 134       1        1
# 163       1        1
# 124       1        1
# 74        1        1
# 18        1        1
# 7         1        1
# 5         1        1
# 125       1        1
# 161       1        1
# 170       0        0
# 181       1        1
# 123       1        1
# 60        0        0
# 44        0        0
# 141       1        1
# 56        1        1
# 173       0        1
# 136       1        1
# 89        1        1
# 63        0        0
# 55        1        1
# 110       1        1
# 166       0        0
# 175       0        1
# 45        0        0
# 22        1        1
# 155       1        1
# 66        1        1
# 37        1        1
# 4         1        1
# 80        1        1
# 178       1        1
# 106       1        1
# 160       1        1

# %%
# Showing a confusion matrix of the results
cm=confusion_matrix(y_test,logistic_preds)
plt.figure(figsize=(8,6))
fg=sns.heatmap(cm,annot=True,cmap="Blues")
figure=fg.get_figure()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Logistic Regression Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Logistic Regression Confusion Matrix')

# %%
# Second model: Decision Tree (depth 5)
tree_model = DecisionTreeClassifier(random_state=42,max_depth=5)
tree_model.fit(X_train, y_train) 
tree_preds = tree_model.predict(X_test)
print("Decision Tree Classification Report:")
print(classification_report(y_test, tree_preds))
# Out:
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74        10
#            1       1.00      0.76      0.86        29
#
#     accuracy                           0.82        39
#    macro avg       0.79      0.88      0.80        39
# weighted avg       0.89      0.82      0.83        39

# %%
# Accuracy score
tree_accuracy = accuracy_score(y_test, tree_preds)
print(f"Decision Tree Accuracy: {tree_accuracy:.2f}")
# Out:
# Decision Tree Accuracy: 0.82

# %%
# Comparing results with the actual values
pd.DataFrame({'actual':y_test,'predict':tree_preds})
# Out:
#      actual  predict
# 83        1        0
# 12        1        1
# 33        0        0
# 113       1        1
# 171       0        0
# 134       1        1
# 163       1        0
# 124       1        0
# 74        1        1
# 18        1        1
# 7         1        0
# 5         1        0
# 125       1        0
# 161       1        1
# 170       0        0
# 181       1        1
# 123       1        0
# 60        0        0
# 44        0        0
# 141       1        1
# 56        1        1
# 173       0        0
# 136       1        1
# 89        1        1
# 63        0        0
# 55        1        1
# 110       1        1
# 166       0        0
# 175       0        0
# 45        0        0
# 22        1        1
# 155       1        1
# 66        1        1
# 37        1        1
# 4         1        1
# 80        1        1
# 178       1        1
# 106       1        1
# 160       1        1

# %%
# Showing a confusion matrix of the results
cm=confusion_matrix(y_test,tree_preds)
plt.figure(figsize=(8,6))
fg=sns.heatmap(cm,annot=True,cmap="Blues")
figure=fg.get_figure()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Decision Tree Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Decision Tree Confusion Matrix')

# %%
# Third Model: Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train) 
rf_preds = rf_model.predict(X_test)
print("Random Forest Classification Report:")
print(classification_report(y_test, rf_preds))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        10
#            1       0.97      0.97      0.97        29
#
#     accuracy                           0.95        39
#    macro avg       0.93      0.93      0.93        39
# weighted avg       0.95      0.95      0.95        39

# %%
# Accuracy score
rf_accuracy = accuracy_score(y_test, rf_preds)
print(f"Decision Tree Accuracy: {rf_accuracy:.2f}")
# Out:
# Decision Tree Accuracy: 0.95

# %%
# Comparing results with the actual values
pd.DataFrame({'actual':y_test,'predict':rf_preds})
# Out:
#      actual  predict
# 83        1        1
# 12        1        1
# 33        0        0
# 113       1        1
# 171       0        1
# 134       1        1
# 163       1        1
# 124       1        1
# 74        1        1
# 18        1        1
# 7         1        0
# 5         1        1
# 125       1        1
# 161       1        1
# 170       0        0
# 181       1        1
# 123       1        1
# 60        0        0
# 44        0        0
# 141       1        1
# 56        1        1
# 173       0        0
# 136       1        1
# 89        1        1
# 63        0        0
# 55        1        1
# 110       1        1
# 166       0        0
# 175       0        0
# 45        0        0
# 22        1        1
# 155       1        1
# 66        1        1
# 37        1        1
# 4         1        1
# 80        1        1
# 178       1        1
# 106       1        1
# 160       1        1

# %%
# Showing a confusion matrix of the results
cm=confusion_matrix(y_test,rf_preds)
plt.figure(figsize=(8,6))
fg=sns.heatmap(cm,annot=True,cmap="Blues")
figure=fg.get_figure()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Random Forest Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Random Forest Confusion Matrix')

# %%
# Fourth Model: Support Vector Machine
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)
svm_model.fit(X_train, y_train)
svm_predictions = svm_model.predict(X_test)
print("SVM Classification Report:")
print(classification_report(y_test, svm_predictions))
# Out:
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        10
#            1       0.91      1.00      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.95      0.85      0.89        39
# weighted avg       0.93      0.92      0.92        39

# %%
# Accuracy score
svm_accuracy = accuracy_score(y_test, svm_predictions)
print(f"Decision Tree Accuracy: {svm_accuracy:.2f}")
# Out:
# Decision Tree Accuracy: 0.92

# %%
# Comparing results with the actual values
pd.DataFrame({'actual':y_test,'predict':svm_predictions})
# Out:
#      actual  predict
# 83        1        1
# 12        1        1
# 33        0        0
# 113       1        1
# 171       0        1
# 134       1        1
# 163       1        1
# 124       1        1
# 74        1        1
# 18        1        1
# 7         1        1
# 5         1        1
# 125       1        1
# 161       1        1
# 170       0        0
# 181       1        1
# 123       1        1
# 60        0        0
# 44        0        0
# 141       1        1
# 56        1        1
# 173       0        1
# 136       1        1
# 89        1        1
# 63        0        0
# 55        1        1
# 110       1        1
# 166       0        0
# 175       0        1
# 45        0        0
# 22        1        1
# 155       1        1
# 66        1        1
# 37        1        1
# 4         1        1
# 80        1        1
# 178       1        1
# 106       1        1
# 160       1        1

# %%
# Showing a confusion matrix of the results
cm=confusion_matrix(y_test,svm_predictions)
plt.figure(figsize=(8,6))
fg=sns.heatmap(cm,annot=True,cmap="Blues")
figure=fg.get_figure()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("SVM Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'SVM Confusion Matrix')

# %%
# Ensemble Model
ensemble_model = VotingClassifier(estimators=[
    ('logistic', logistic_model),
    ('tree', tree_model),
    ('rf', rf_model),
    ('svm', svm_model)
], voting='hard')
ensemble_model.fit(X_train, y_train)
ensemble_preds = ensemble_model.predict(X_test)
print("Ensemble Model Classification Report:")
print(classification_report(y_test, ensemble_preds))
# Out:
# Ensemble Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        10
#            1       0.97      0.97      0.97        29
#
#     accuracy                           0.95        39
#    macro avg       0.93      0.93      0.93        39
# weighted avg       0.95      0.95      0.95        39

# %%
# Accuracy score
ensemble_accuracy = accuracy_score(y_test, ensemble_preds)
print(f"Ensemble Model Accuracy: {ensemble_accuracy:.2f}")
# Out:
# Ensemble Model Accuracy: 0.95

# %%
# Comparing results with the actual values
pd.DataFrame({'actual':y_test,'predict':ensemble_preds})
# Out:
#      actual  predict
# 83        1        1
# 12        1        1
# 33        0        0
# 113       1        1
# 171       0        1
# 134       1        1
# 163       1        1
# 124       1        1
# 74        1        1
# 18        1        1
# 7         1        0
# 5         1        1
# 125       1        1
# 161       1        1
# 170       0        0
# 181       1        1
# 123       1        1
# 60        0        0
# 44        0        0
# 141       1        1
# 56        1        1
# 173       0        0
# 136       1        1
# 89        1        1
# 63        0        0
# 55        1        1
# 110       1        1
# 166       0        0
# 175       0        0
# 45        0        0
# 22        1        1
# 155       1        1
# 66        1        1
# 37        1        1
# 4         1        1
# 80        1        1
# 178       1        1
# 106       1        1
# 160       1        1

# %%
# Showing a confusion matrix of the results
cm =confusion_matrix(y_test,ensemble_preds)
plt.figure(figsize=(8,6))
fg=sns.heatmap(cm,annot=True,cmap="Blues")
figure=fg.get_figure()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Ensemble Classifier Confusion Matrix")
plt.show()

# %%
# Calculate metrics for each model

model_preds = {
    'Logistic Regression': logistic_preds,
    'Random Forest': rf_preds,
    'SVM': svm_predictions,
    'Decision Trees': tree_preds,
    'Ensemble Models': ensemble_preds  # Enable probability for AUC-ROC
}
results = {'Model': [], 'Accuracy': [], 'AUC-ROC': [], 'Precision': [], 'Recall': [], 'F1-Score': [], 'AUC-ROC': []}

for model_name, y_pred in model_preds.items():
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    auc_roc = roc_auc_score(y_test, y_pred)
    
    # Append results to the dictionary
    results['Model'].append(model_name)
    results['Accuracy'].append(accuracy)
    results['Precision'].append(precision)
    results['Recall'].append(recall)
    results['F1-Score'].append(f1)
    results['AUC-ROC'].append(auc_roc)

# Convert results to NumPy array for plotting
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'AUC-ROC']
values = np.array([results[m] for m in metrics])

# Plot the results
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.set_palette("ch:s=.25,rot=-.25")

x = np.arange(len(model_preds))  # X positions for bars
width = 0.15  # Width of bars

# Plot each metric
for i, metric in enumerate(metrics):
    plt.bar(x + i * width, values[i], width, label=metric)

plt.xticks(x + width, results['Model'], rotation=30, ha='right')
plt.ylabel("Score")
plt.title("Model Performance Comparison")
plt.legend()
plt.show()

# Print the metrics for each model
for model_name in results['Model']:
    print(f"{model_name}:")
    for metric in metrics:
        print(f"  {metric}: {results[metric][results['Model'].index(model_name)]:.2f}")
# Out:
# Logistic Regression:
#   Accuracy: 0.92
#   Precision: 0.93
#   Recall: 0.92
#   F1-Score: 0.92
#   AUC-ROC: 0.85
# Random Forest:
#   Accuracy: 0.95
#   Precision: 0.95
#   Recall: 0.95
#   F1-Score: 0.95
#   AUC-ROC: 0.93
# SVM:
#   Accuracy: 0.92
#   Precision: 0.93
#   Recall: 0.92
#   F1-Score: 0.92
#   AUC-ROC: 0.85
# Decision Trees:
#   Accuracy: 0.82
#   Precision: 0.89
#   Recall: 0.82
#   F1-Score: 0.83
#   AUC-ROC: 0.88
# Ensemble Models:
#   Accuracy: 0.95
#   Precision: 0.95
#   Recall: 0.95
#   F1-Score: 0.95
#   AUC-ROC: 0.93

# %%
# Create a DataFrame for comparison
comparison = pd.DataFrame({'Actual':y_test,'Logistic Regression':logistic_preds,'Decision Tree':tree_preds,'Random Forest':rf_preds,'Ensemble Models':ensemble_preds})
comparison
# Out:
#      Actual  Logistic Regression  Decision Tree  Random Forest  \
# 83        1                    1              0              1
# 12        1                    1              1              1
# 33        0                    0              0              0
# 113       1                    1              1              1
# 171       0                    1              0              1
# 134       1                    1              1              1
# 163       1                    1              0              1
# 124       1                    1              0              1
# 74        1                    1              1              1
# 18        1                    1              1              1
# 7         1                    1              0              0
# 5         1                    1              0              1
# 125       1                    1              0              1
# 161       1                    1              1              1
# ...
